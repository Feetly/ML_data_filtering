# %%
import matplotlib.pyplot as plt
i = [0.01,0.05,0.1,0.2,0.4,0.7,1,2.5,3]
v1 = [0.540,0.550,0.570,0.580,0.600,0.610,0.615,0.624,0.630]
v2 = [0.497,0.533,0.545,0.557,0.570,0.577,0.590,0.620,0.625]
v3 = [0.459,0.506,0.525,0.544,0.565,0.573,0.583,0.615,0.621]
v4 = [0.430,0.470,0.490,0.510,0.545,0.562,0.573,0.602,0.608]

plt.plot(v1,i,"-b",Label='26 Deg.')
plt.plot(v2,i,"-g",Label='30 Deg.')
plt.plot(v3,i,"-r",Label='40 Deg.')
plt.plot(v4,i,"-y",Label='50 Deg.')
plt.title('Id Vs Vd')
plt.xlabel('Vd in V')
plt.ylabel('Id in mA')
plt.legend(loc='upper left')
plt.ylim(0,3)
plt.savefig('plot2.png')
plt.show()
